# %% [markdown]
# <a href="https://colab.research.google.com/github/hirru/GenAI/blob/main/ColdEmail_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# LangChain - A framework that helps to integrate LLM's into applications
# %pip install -qU langchain-groq

# %%
# Groq - A cloud platform that can help run models on cloud
from langchain_groq import ChatGroq

llm = ChatGroq(
    temperature=0,
    groq_api_key="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",
    model_name="llama-3.1-70b-versatile"
)

response = llm.invoke("The first person to land on moon was...")
print(response.content)
# Out:
# The first person to land on the moon was Neil Armstrong. He stepped onto the lunar surface on July 20, 1969, as part of the Apollo 11 mission.

# %%
# Chroma is the open-source AI application database
# %pip install chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 604.0/604.0 kB 18.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 62.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 18.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 67.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 69.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 3.2 MB/s eta 0:00:00
# ...

# %%
# %pip install -qU langchain_community beautifulsoup4
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 36.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 42.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.0 MB/s eta 0:00:00

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://jobs.nike.com/job/R-39446?from=job%20search%20funnel")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# Apply for Lead, Motion Capture Studio Innovation
#
# ...

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):
        """
)

chain_extract = prompt_extract | llm
res = chain_extract.invoke(input={'page_data': page_data})
print(res.content)
type(res.content)
# Out:
# ```json
# {
#   "role": "Lead, Motion Capture Studio Innovation",
#   "experience": "Minimum of 5 yrs' experience working in motion capture industry and/or optimizing motion caption system(s) and running collections for a variety of studies in a large lab setting",
#   "skills": [
#     "Motion Capture experience",
#     "Trouble shooting and creative problem solving",
#     "Verbal and written communication",
#     "Familiarity with biomechanics, physiology, and/or other sport research lab settings",
#     "Experience with markered, markerless motion capture and in ground force plates",
#     "Master-level documentation and process building rigor",
#     "Expert user with contemporary knowledge of motion capture technology, including hardware, software, and environment requirements",
#     "Experience with game engines, and motion capture software (Nexus, Shogun, etc.)",
#     "Prior project team management skills"
#   ],
# ...

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# {'role': 'Lead, Motion Capture Studio Innovation',
#  'experience': "Minimum of 5 yrs' experience working in motion capture industry and/or optimizing motion caption system(s) and running collections for a variety of studies in a large lab setting",
#  'skills': ['Motion Capture experience',
#   'Trouble shooting and creative problem solving',
#   'Verbal and written communication',
#   'Familiarity with biomechanics, physiology, and/or other sport research lab settings',
#   'Experience with markered, markerless motion capture and in ground force plates',
#   'Master-level documentation and process building rigor',
#   'Expert user with contemporary knowledge of motion capture technology, including hardware, software, and environment requirements',
#   'Experience with game engines, and motion capture software (Nexus, Shogun, etc.)',
#   'Prior project team management skills'],
# ...

# %%
type(json_res)
# Out:
# dict

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/codebasics/project-genai-cold-email-generator/refs/heads/main/my_portfolio.csv')
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# ...

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])
# Out:
# /root/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:02<00:00, 37.5MiB/s]

# %%
links = collection.query(query_texts=job['skills'], n_results=2).get('metadatas', [])
links
# Out:
# [[{'links': 'https://example.com/android-portfolio'},
#   {'links': 'https://example.com/ml-python-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/devops-portfolio'}],
#  [{'links': 'https://example.com/wordpress-portfolio'},
#   {'links': 'https://example.com/android-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/python-portfolio'}],
#  [{'links': 'https://example.com/java-portfolio'},
#   {'links': 'https://example.com/devops-portfolio'}],
#  [{'links': 'https://example.com/devops-portfolio'},
#   {'links': 'https://example.com/full-stack-js-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/android-tv-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/ios-ar-portfolio'}],
#  [{'links': 'https://example.com/devops-portfolio'},
# ...

# %%
job = json_res
job['skills']
# Out:
# ['Motion Capture experience',
#  'Trouble shooting and creative problem solving',
#  'Verbal and written communication',
#  'Familiarity with biomechanics, physiology, and/or other sport research lab settings',
#  'Experience with markered, markerless motion capture and in ground force plates',
#  'Master-level documentation and process building rigor',
#  'Expert user with contemporary knowledge of motion capture technology, including hardware, software, and environment requirements',
#  'Experience with game engines, and motion capture software (Nexus, Shogun, etc.)',
#  'Prior project team management skills']

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}

        ### INSTRUCTION:
        You are Mohan, a business development executive at AtliQ. AtliQ is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools.
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability,
        process optimization, cost reduction, and heightened overall efficiency.
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of AtliQ
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase Atliq's portfolio: {link_list}
        Remember you are Mohan, BDE at AtliQ.
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):

        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Expert Motion Capture Solutions for NSRL's Vision and Strategy
#
# Dear Hiring Manager,
#
# I came across the job description for the Lead, Motion Capture Studio Innovation role at NSRL, and I was impressed by the organization's commitment to innovation and excellence. As a Business Development Executive at AtliQ, I believe our company can provide the expertise and solutions to support NSRL's vision and strategy in motion capture technology.
#
# AtliQ is an AI & Software Consulting company dedicated to facilitating the seamless integration of business processes through automated tools. Our team of experts has extensive experience in developing and implementing cutting-edge solutions for various industries, including motion capture and biomechanics.
#
# ...
